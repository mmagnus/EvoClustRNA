# %% [markdown]
# # RNA-Puzzle 13

# %%
from rna_tools.tools.rna_alignment.rna_alignment import RNAalignment

# %%
alignment = RNAalignment('test_data/rp13/rp13finalX_noSSperSeq_ref.sto')

# %%
alignment.plot()
# Out:
# Rchie: plot saved to rchie.png

# %%
alignment
# Out:
# SingleLetterAlphabet() alignment with 6 rows and 130 columns
# ---GGGUCGUGACUGGCGAAC-----------------------...C-- rp13
# GCUCUCGCGCGACUGGCGACUUU---------------------...C-- nc9445
# ---GCGCAGUGACUGACGACGAU---------------------...C-- nzaaox
# -ACCUUGCGCAACUGGCGAAUC-CUGGGGCUGCCGCC-GGCAGU...CA- nc3295
# -ACCUUGCGCGACUGGCGAAUC-CUGAAGCUGCUUUG-AGCGGC...CAG cp0016
# ---xxxxxxx----xxxx--------------------------...x-- x
